# %%
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
os.listdir("/home/sean")
# Out:
# ['.gnupg',
#  'Pictures',
#  '.condarc',
#  '.config',
#  'Desktop',
#  '.ICEauthority',
#  'Templates',
#  'examples.desktop',
#  '.mozilla',
#  '.bash_history',
#  'anaconda3',
#  '.sudo_as_admin_successful',
#  '.gitconfig',
#  '.bashrc',
#  '.bash_logout',
#  '.conda',
#  'Documents',
#  '.vscode',
#  '.ssh',
#  '.pki',
#  'Music',
#  '.thunderbird',
#  'Videos',
#  '.ipynb_checkpoints',
#  'testrepo',
#  '.anaconda',
#  '.profile',
#  '.ipython',
#  'Downloads',
#  '.jupyter',
#  '.cache',
#  'iPython Notebooks',
#  'Public',
#  '.local']

# %%
testImg = mpimg.imread('/home/sean/Pictures/python image.jpg')

# %%
plt.imshow(testImg)

# %% [markdown]
# ----------

# %%
images = []

# %%
def getImages (fun, dir):
    for img in fun:
        images.append(mpimg.imread(dir + "/" + img))

# %%
getImages(os.listdir("/home/sean/Pictures"), "/home/sean/Pictures")

# %%
plt.imshow(images[0])
